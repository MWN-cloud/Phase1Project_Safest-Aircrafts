# %% [markdown]
# #**Flying High: Choosing Safe Aircraft for Growth**

# %% [markdown]
# #**Business Understanding**
# The business is pursuing a new strategic venture in the aviation sector. The objective is to **assist the head of the newly established aviation division** in identifying the **risks associated with aircraft operations**, including **potential operational mishaps** for both **commercial and private aircraft**. The aim is to provide **evidence-based** insights to support informed **decision-making** based on the gathered data.

# %% [markdown]
# ## **Problem Statement**
# The company is **expanding into the aviation sector**, focusing on the purchase and operation of both commercial and private aircraft. However, there is a **lack of comprehensive understanding regarding the associated risks**, **operational mishaps**, and **safety concerns** related to these aircraft types. The challenge is to **identify the aircraft models** that pose the **lowest risk** and provide **data-driven insights** that will enable the head of the new aviation division to make informed, evidence-based decisions on which aircraft to purchase and operate for the business's success and growth

# %% [markdown]
# ###**Objectives**
#
#
# 1.   Identifying the safest and unsafest aircrafts and their Characteristics
# 2.   Identifying the major cause of accidents
# 3.   Identifying the effect of weather on accidents
# 4.   Does the type of build affect the number of fatalities
# 5.   Which year had the most casualties

# %% [markdown]
# #**Methodology**
#
# The data is obtained from the Kaggle Repository.
# The below is the methods pursued to achieve the reccomendations below;
# 1. **Data Cleaning**
# *   Removing null columns and rows
# *   Harmonising data to prevent duplication
# 2. **Descriptive Statistics**
# *   Identifying correlations
# *   Introducing columns in relation to existing data to enrich the data set
# 3. **Visualisation**
# *   Using different plots **focusing on the 5 key objectives set** with the support of matplotlib and seaborn to achieve relational data and insights
# 4. **Conclusion and Recommendations**
# *   Developing actionable insights from the analysis achieved

# %% [markdown]
# #**Success Criteria**
#
# **Ranking Aircraft Safety:**
#
# Rank aircraft based on accident rates and fatalities.
# Identify key risk factors.
#
# **Categorizing Accident Causes:**
#
# Classify and quantify major accident causes
# Provide actionable recommendations for risk mitigation
#
# **Weather Impact on Accidents:**
#
# Quantify how weather conditions correlate with accident frequency and severity
#
# **Fatalities by Aircraft Type:**
#
# Identify differences in fatalities between commercial and private aircraft.
# Offer recommendations on prioritizing aircraft types based on safety.
#
# **Identifying Peak Years for Casualties:**
#
# Provide time-based insights into trends and potential external factors influencing accidents.
#
# **Actionable Insights and Recommendations:**
#
# Provide clear, data-driven recommendations for aircraft purchasing and operations.
# Focus on safety, risk mitigation, and cost-effectiveness in decisions.

# %% [markdown]
# #**Limitations and Assumptions**
#
# ##**Limitations**
#
#
# 1.   The data had some missing items and some named as unknown which reduced the accuracy of the dataset
#
#
# ##**Assumptions**
#
#
# 1.   The total classification of injuries summed up gave the total number of passengers in one flight
# 2. Year 2020 had the highest number of fatalities. This could be due to the world-wide lockdown in relation to Covid19 and therefore a high increase in recreational activities to reduce boredom
# 3. Personal flights were related to recreational purposes

# %% [markdown]
# #**Data Understanding**

# %% [markdown]
# ##**Data Discovery**

# %%
#importing libraries
#importing data

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
aviation_df = pd.read_csv('AviationData.csv', encoding='latin1')
# Out:
# <ipython-input-1-b9f7e159fc09>:8: DtypeWarning: Columns (6,7,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   aviation_df = pd.read_csv('AviationData.csv', encoding='latin1')

# %%
aviation_df.shape
# Out:
# (88889, 31)

# %%
aviation_df.columns
# Out:
# Index(['Event.Id', 'Investigation.Type', 'Accident.Number', 'Event.Date',
#        'Location', 'Country', 'Latitude', 'Longitude', 'Airport.Code',
#        'Airport.Name', 'Injury.Severity', 'Aircraft.damage',
#        'Aircraft.Category', 'Registration.Number', 'Make', 'Model',
#        'Amateur.Built', 'Number.of.Engines', 'Engine.Type', 'FAR.Description',
#        'Schedule', 'Purpose.of.flight', 'Air.carrier', 'Total.Fatal.Injuries',
#        'Total.Serious.Injuries', 'Total.Minor.Injuries', 'Total.Uninjured',
#        'Weather.Condition', 'Broad.phase.of.flight', 'Report.Status',
#        'Publication.Date'],
#       dtype='object')

# %%
#Understanding the dataframe -
#1.no of rows and columns
#2.data type
#3.number of non-null values per column
aviation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88889 entries, 0 to 88888
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Investigation.Type      88889 non-null  object
#  2   Accident.Number         88889 non-null  object
#  3   Event.Date              88889 non-null  object
#  4   Location                88837 non-null  object
#  5   Country                 88663 non-null  object
#  6   Latitude                34382 non-null  object
#  7   Longitude               34373 non-null  object
#  8   Airport.Code            50132 non-null  object
#  9   Airport.Name            52704 non-null  object
#  10  Injury.Severity         87889 non-null  object
#  11  Aircraft.damage         85695 non-null  object
#  12  Aircraft.Category       32287 non-null  object
#  13  Registration.Number     87507 non-null  object
#  14  Make                    88826 non-null  object
#  15  Model                   88797 non-null  object
#  16  Amateur.Built           88787 non-null  object
#  17  Number.of.Engines       82805 non-null  float64
#  18  Engine.Type             81793 non-null  object
#  19  FAR.Description         32023 non-null  object
#  20  Schedule                12582 non-null  object
#  21  Purpose.of.flight       82697 non-null  object
#  22  Air.carrier             16648 non-null  object
#  23  Total.Fatal.Injuries    77488 non-null  float64
#  24  Total.Serious.Injuries  76379 non-null  float64
#  25  Total.Minor.Injuries    76956 non-null  float64
#  26  Total.Uninjured         82977 non-null  float64
#  27  Weather.Condition       84397 non-null  object
#  28  Broad.phase.of.flight   61724 non-null  object
#  29  Report.Status           82505 non-null  object
#  30  Publication.Date        75118 non-null  object
# dtypes: float64(5), object(26)
# memory usage: 21.0+ MB

# %%
#Generating descriptive analysis of the data
aviation_df.describe()
# Out:
#        Number.of.Engines  Total.Fatal.Injuries  Total.Serious.Injuries  \
# count       82805.000000          77488.000000            76379.000000
# mean            1.146585              0.647855                0.279881
# std             0.446510              5.485960                1.544084
# min             0.000000              0.000000                0.000000
# 25%             1.000000              0.000000                0.000000
# 50%             1.000000              0.000000                0.000000
# 75%             1.000000              0.000000                0.000000
# max             8.000000            349.000000              161.000000
#
#        Total.Minor.Injuries  Total.Uninjured
# count          76956.000000     82977.000000
# mean               0.357061         5.325440
# std                2.235625        27.913634
# min                0.000000         0.000000
# 25%                0.000000         0.000000
# 50%                0.000000         1.000000
# 75%                0.000000         2.000000
# max              380.000000       699.000000

# %% [markdown]
# ##**Data Cleaning**

# %%
#Identifying number of null values per column
aviation_df.isna().sum()
# Out:
# Event.Id                      0
# Investigation.Type            0
# Accident.Number               0
# Event.Date                    0
# Location                     52
# Country                     226
# Latitude                  54507
# Longitude                 54516
# Airport.Code              38757
# Airport.Name              36185
# Injury.Severity            1000
# Aircraft.damage            3194
# Aircraft.Category         56602
# Registration.Number        1382
# Make                         63
# Model                        92
# Amateur.Built               102
# Number.of.Engines          6084
# Engine.Type                7096
# FAR.Description           56866
# Schedule                  76307
# Purpose.of.flight          6192
# Air.carrier               72241
# Total.Fatal.Injuries      11401
# Total.Serious.Injuries    12510
# Total.Minor.Injuries      11933
# Total.Uninjured            5912
# Weather.Condition          4492
# Broad.phase.of.flight     27165
# Report.Status              6384
# Publication.Date          13771
# dtype: int64

# %%
#Dropping columns with high number of null values
aviation_df_cln = aviation_df.drop(columns=['Airport.Code','Airport.Name','Latitude','Longitude','Aircraft.Category','FAR.Description','Air.carrier','Schedule'])

# %%
#8 columns dropped
aviation_df_cln.shape
# Out:
# (88889, 23)

# %%
#verification of the dropped columns
aviation_df_cln.isna().sum()
# Out:
# Event.Id                      0
# Investigation.Type            0
# Accident.Number               0
# Event.Date                    0
# Location                     52
# Country                     226
# Injury.Severity            1000
# Aircraft.damage            3194
# Registration.Number        1382
# Make                         63
# Model                        92
# Amateur.Built               102
# Number.of.Engines          6084
# Engine.Type                7096
# Purpose.of.flight          6192
# Total.Fatal.Injuries      11401
# Total.Serious.Injuries    12510
# Total.Minor.Injuries      11933
# Total.Uninjured            5912
# Weather.Condition          4492
# Broad.phase.of.flight     27165
# Report.Status              6384
# Publication.Date          13771
# dtype: int64

# %%
#Identifying unique values to harmonise data
aviation_df_cln.Make.unique().tolist()
# Out:
# ['Stinson',
#  'Piper',
#  'Cessna',
#  'Rockwell',
#  'Mcdonnell Douglas',
#  'North American',
#  'Beech',
#  'Bellanca',
#  'Navion',
#  'Enstrom',
#  'Smith',
#  'Bell',
#  'Grumman',
#  'Beechcraft',
#  'Maule',
#  'Air Tractor',
#  'Aerospatiale',
#  'Mooney',
#  'Boeing',
#  'Curtis',
#  'Schleicher',
#  'Quickie',
#  'Lockheed',
#  'Embraer',
#  'Hughes',
#  'Swearingen',
#  'De Havilland',
#  'Bell Helicopter',
#  'Bede Aircraft',
#  'Convair',
#  'Beachner',
#  'Canadair',
#  'Douglas',
#  'Sons Mustang',
#  'Dassault/sud',
#  'Sikorsky',
#  'Bell/textron',
#  'Robertson',
#  'Aeronca',
#  'Smith Miniplane',
#  'Mitsubishi',
#  'Mcdonnell-douglas',
#  'Taylorcraft',
#  'Ted Smith',
#  'Robinson',
#  'Raven',
#  'Ercoupe',
#  'Rockwell Comdr',
#  'Howard Aircraft Corp.',
#  'Porterfield',
#  'Nihon',
#  'Great Lakes',
#  'Balloon Works',
#  'Pitts',
#  'Fairchild Hiller',
#  'Kaman',
#  'Weatherly',
#  'Eagle',
#  'Barnes',
#  'Schweizer',
#  'Starduster Ii',
#  'Homebuilt',
#  'Smith Mini',
#  'Smith Aerostar',
#  'Rockwell Intl',
#  'Hiller',
#  'Schreder',
#  'Varga',
#  'Hatz',
#  'Nord Aviation',
#  'Crook',
#  'American Yankee',
#  'Helio',
#  'Colonial',
#  'Gulfstream American',
#  'Benson',
#  'Luscombe',
#  'Mckinley Eaa',
#  'Airmate',
#  'B??lkow',
#  'Snow',
#  'Rockwell Commander',
#  'Rotorway',
#  'Gulfstream',
#  'Champion',
#  'Fournier Aviation',
#  'Curtiss-wright',
#  'Aero Commander',
#  'Mbb-bolkow',
#  'Piper-aerostar',
#  'Rockwell Intl.',
#  'Ryan',
#  'Jurca',
#  'Martin-pitts',
#  'S.n.i.a.s.',
#  'Goodyear',
#  'Rand',
#  'Rutan',
#  'Burkhart Grob Flugzeugbah',
#  'Sud Aviation',
#  'Avres Corp.',
#  'Grum Amer',
#  'Evans Aircraft',
#  'Schweizer Sgs',
#  'Ayres',
#  'Stampe Renard',
#  'Fairchild',
#  'Pitts Special',
#  'Tailwind',
#  'Hiller-soloy',
#  'Aerotek-pitts',
#  'Avian Balloon',
#  'Hartman',
#  'Spezio',
#  'Dauntless',
#  'Mbb',
#  'Bell/soloy',
#  'Raz-mut',
#  'Christian',
#  'Funk Aircraft Co.',
#  'Mong Sport',
#  'Rayan',
#  'Starfire',
#  'Osprey',
#  'Hudson',
#  'Continental',
#  'Gates Learjet',
#  'Scorpion',
#  'Thunder Balloons, Ltd.',
#  'Moore Bell',
#  'Blanik',
#  'Taylor',
#  'Lake',
#  'Brantley',
#  'Bryan',
#  'Bell 47g-3b',
#  'Volmer Aircraft',
#  'Citabria',
#  'Martin',
#  'Nash Cassutt Racer',
#  'Playmate',
#  'Oldfield',
#  'Bac',
#  'Broyill-cowan-murray',
#  'Erco',
#  'Brantly',
#  'Callair',
#  'Consolidated Aeronautics Inc.',
#  'Continental Mk5a',
#  'Arctic',
#  'Thurston',
#  'Swanson',
#  'Adams',
#  'Mignet',
#  'Starduster',
#  'Hardie',
#  'Savage',
#  'Starke',
#  'Mccall',
#  'Fokker',
#  'Scheicher',
#  'Bensen',
#  'Wing',
#  'Gregg',
#  'Learjet',
#  'Mcclary',
#  'Midget',
#  'Na',
#  'I.c.a. Brasov - Romania',
#  'Southern Airmotive Corp Sac',
#  'Barrett',
#  'Varieze',
#  'Cameron Ballon',
#  'I.c.a. Brasov',
#  'Peter Clark',
#  'Davis',
#  'Bellance',
#  'Rockwell International',
#  'Downer Aircraft Industries',
#  'Pterodactyl',
#  'Ryan Aeronautics',
#  'Grumman American',
#  nan,
#  'Clancy',
#  'Bell-cont 42g',
#  'Britten-norman',
#  'Waco',
#  'Goans',
#  'Glassflugel',
#  'Pietenpol',
#  'Miller',
#  'Aeronca Champion',
#  'Coot',
#  'Breezy',
#  'Junior Ace',
#  'Globe',
#  'Lark (i.c.a.)',
#  'Republic',
#  "Rockwell Int't",
#  'Mong',
#  'American',
#  'Firefly',
#  'Texas Helicopter Corp.',
#  'Thorp',
#  'Rotorway Aircraft, Inc.',
#  'Omac',
#  'Bucker Jungmann',
#  'Steen',
#  'Alon',
#  'Austin',
#  'Morrisey',
#  'Eipper Mx Ii Quicksilver',
#  'Hallquist',
#  'Aeronca Champ',
#  'Q-berry',
#  'Oar',
#  'Siai Marchetti',
#  'Corben',
#  'Sonerai',
#  'Bell Helicopter Textron',
#  'Boeing Stearman',
#  'Eiriavion Oy',
#  'Condor',
#  'Eaa',
#  'Von Berg',
#  'Menees',
#  'Engineering & Research',
#  'Dragon Fly',
#  'Auster',
#  'Air & Space',
#  'Quicksilver',
#  'Cassutt',
#  'Mustang',
#  'Lawson Special',
#  'Cameron',
#  'Bently',
#  'Wayne Ison',
#  'Lindgren Evans',
#  'American Aviation',
#  'Falkenthal',
#  "Villine's",
#  'Consolidated Aero',
#  'Davenport',
#  'Schempp-hirth',
#  'Bennet',
#  'Vari-eze',
#  'Long-ez',
#  'Fairchild/swearingen',
#  'Flitecraft',
#  'Foster',
#  'Scorpion Too',
#  'Navy',
#  'Glasflugel',
#  'Tanke',
#  'Wainscott',
#  'Ken Brock',
#  'Saville Hummer',
#  'Cougar',
#  'General Balloon',
#  'Raven Industries',
#  'Boeing Vertol',
#  'Tomcat',
#  'Bowers Flybaby',
#  'Volksplane',
#  'E.l. Craig',
#  'Eipper-formance',
#  'C. Eff',
#  'J.a.mullan',
#  'Flagg',
#  'Arctic Aircraft',
#  'Vanhoose/scorpio',
#  'Johnson, Douglas L.',
#  'Short Bros.',
#  'Rolladen-schneider',
#  'Froehlich',
#  'Temco',
#  'Amateur Built',
#  'Mcdonald Douglas',
#  'Tifft-v',
#  'Beagle Aircraft',
#  'Aerosport',
#  'Cgs Aviation',
#  'Gates Lear Jet',
#  'Frank Turben',
#  'Hollman',
#  'Burke-parker',
#  'Norman Negus',
#  'Piccard',
#  'Javelin Aircraft',
#  'Teal',
#  'Willbird',
#  'Israel Aircraft Industries',
#  'Cromwell/pitts',
#  'Smith, Ted Aerostar',
#  'Obryon',
#  'Pace',
#  'Pratt-read',
#  'John Tylenda',
#  'Monnett',
#  'Scheibe Flugzeugbau',
#  'Eagle (ultralight)',
#  'Harrison Volmer',
#  'Dodd',
#  'Beckner',
#  'Glasair',
#  'Rand Kr1',
#  'Rotec',
#  'Vans Aircraft',
#  'Burkhart Grob',
#  'Eaa Biplane',
#  'Gray',
#  'Brown',
#  'Weedhopper',
#  "Gemini Int'l.",
#  'Molino Oy',
#  'Manta',
#  'Waspair',
#  'Consolidated-vultee',
#  'Murrayair',
#  'Kit Built (rotorway)',
#  'Ware Teenie',
#  'Eagle Aircraft Co.',
#  'Anderson, Greenwood',
#  'Continental Copters',
#  'Partenavia',
#  'Cgs',
#  'Let',
#  'Ercoupe (eng & Research Corp.)',
#  'Mitchell',
#  'Wizard',
#  'Walston',
#  'Pteradactyl',
#  'Spencer',
#  'Brantly Helicopter',
#  'Logan',
#  'Tuk Gregory',
#  'Airmass',
#  'Swift',
#  'Ultralight Flight',
#  'Carter',
#  'Rietman',
#  'Boland',
#  'North American Rockwell Corp.',
#  'Holmes',
#  'Fairchild Swearingen',
#  'Eippen Aircraft',
#  'Goldwing',
#  'Skypower',
#  'Vector',
#  'Rogers',
#  'Cummings Quickie',
#  'Forney',
#  'Eipper',
#  'Schaffer-provencher',
#  'Intl Ultralight',
#  'Parson',
#  'Aircoupe',
#  'Herpst',
#  'Grumman-schweizer',
#  'Siai-marchetti',
#  'Ryan-navion',
#  'Ultralight Engineering',
#  'Artic Aircraft Corp.',
#  'Mcdonald',
#  'Yarnell',
#  'Barnstormer',
#  'Link-johnson-chessman',
#  'Rotec Engineering, Inc.',
#  'Sunburst',
#  'Dg',
#  'Johnson',
#  'Monerai',
#  'Texas Helicopter',
#  'Dial-thorp',
#  'Para-sail',
#  'Lombard Dilley',
#  'Meyers Aircraft Co.',
#  'Mareik-bensen',
#  'Eastern Ultralight',
#  'Stolp',
#  'Garlick',
#  'Eipper Formance',
#  'Prout',
#  'Kate',
#  'Smith-poston',
#  'American Aerolights',
#  'Aleson',
#  'Bowlin',
#  'Monnett - Larsen',
#  'Thorpe',
#  'Hamilton',
#  'Long',
#  'Twitchell',
#  'Clark',
#  'Rotec/botsford',
#  'Vans-rupert',
#  'Mattison',
#  'Gilbert L. Houston',
#  'Eames',
#  'Viking',
#  'Flug-und Fahrzeugwerke (ffa)',
#  'Curtiss',
#  'Wsk Pzl Mielec',
#  'J. Roberts',
#  'Sportavia-putzer',
#  'Gyaki',
#  'Easy Riser',
#  'American Eagle',
#  'Hackett/mckown',
#  'E.r. Hutson',
#  'Condor Ii',
#  'Finamore',
#  'Sopwith',
#  'Breezy Rlu',
#  'Rand Robinson',
#  'Dimaria',
#  'Laister',
#  'Vangrunsven',
#  'Berkshire',
#  'Schippers',
#  'Kane',
#  'Pietenpal',
#  'Chamberlain',
#  'Monke',
#  'Trager',
#  'Pestes',
#  'Grau',
#  'Fisher',
#  'Swain',
#  'Naval Aircraft Factory',
#  'Black',
#  'Zenair',
#  'Pietonpol-imrie',
#  'Beemer',
#  'Aerostar',
#  'Berwin',
#  'Camair Aircraft Corp.',
#  'Lowther',
#  'Pierce',
#  'Burnett',
#  'Jodel',
#  'Casa',
#  'Scarboro',
#  'Corbin',
#  'Aerotek',
#  'Arrow Aircraft Co.',
#  'Demeter',
#  'Leonard',
#  'Manta Products',
#  'Teratorn',
#  'Grieme',
#  'Midwest Microlites -',
#  'Semco',
#  'Bird',
#  'Pioneer',
#  'Prell',
#  'Catto',
#  'Starflight',
#  'Stewart',
#  'Mockrud',
#  'Edwards',
#  'Waspair Tomcat',
#  'West-heckman',
#  'Kuster',
#  'Johnston',
#  'Bucker Flugzeugbau',
#  'British Aircraft Corp. (bac)',
#  'Warren',
#  'Stol Aircraft',
#  'Pterodactyl/lambert',
#  'Clarks Pitt Special',
#  'Eipper Quicksilver',
#  'Wormley',
#  'Brandt',
#  'Mortensen',
#  'Kruer',
#  'Anderson Aircraft Corp.',
#  'Fueslein',
#  'Kecskes',
#  'Jilek-smith Miniplane',
#  'Gulfstream-schweizer',
#  'Eipper Quicksiver E',
#  'Pilatus',
#  'Kimbal',
#  'Hordemann',
#  'Kemmeyer',
#  'Hawker Siddeley',
#  'Lanny Rundell',
#  'Alderfer',
#  'Deley Starduster',
#  'Hight Smaragd',
#  'Highcraft',
#  'Popelka',
#  'Short Brothers',
#  'Baking',
#  'Wichawk',
#  'Jordan',
#  'Delts Wing Kites',
#  'Airbus Industrie',
#  'Bradey',
#  'Westland Helicopters',
#  'Morton',
#  'Teman',
#  'Jodel-bernier',
#  'Gary Wilson',
#  'Rider',
#  'Lazair',
#  'Kepple',
#  'Skov-papworth',
#  'Paul S. Kerr',
#  'Motorized Gliders',
#  'Vickers',
#  'Sabreliner Corp.',
#  'Rygg',
#  'Striplin',
#  'Yaple, Robert G.',
#  'Young-losey',
#  'Jodell',
#  'Wells/rand',
#  'British Aerospace',
#  'Lark Aviation',
#  'Dassault',
#  'Bach',
#  'Gordon',
#  'Shuey',
#  'Moseley/scorpion',
#  'Maupin',
#  'Harvey',
#  'Panaplane',
#  'Ultraclassics',
#  'Vampire',
#  'Chance Vought',
#  'Robert H. Low',
#  'Keith A Smith',
#  'Gardner',
#  'Heinemann',
#  'American Aviation Corp. (aac)',
#  'Sigers',
#  'Teratorn Acft Inc.',
#  'Eagle Balloons',
#  'Gross',
#  'Southern',
#  'Shark',
#  'Swanson/bensen',
#  'Vari',
#  'Alleva',
#  'Bengtson',
#  'Robert Mcdonnell',
#  'Lee M. Brown',
#  'Bowers',
#  'Birdman Enterprises',
#  'Owen Robert R',
#  'Martin Company',
#  'Bliss Corbin',
#  'Unknown',
#  'Sturges',
#  'Folke Wulf',
#  'American Aircraft',
#  'Fornaire',
#  'Brown, R. M. Jr.',
#  'Pzl-mielec',
#  'Bowen-powell',
#  'Beasley, Gerald L.',
#  'Teratorn Aircraft, Inc.',
#  'William Freeman',
#  'Murphy-charles',
#  'Rally Rotec',
#  'Hall-cavalier',
#  'Christen Eagle',
#  'Soneria',
#  'Olson',
#  'Gable',
#  'Ginn',
#  'Harper/cricri',
#  'Meyers',
#  'Brubaker',
#  'Pietenpol-grega',
#  'Ultraflight',
#  'Istenes',
#  'Wagner',
#  'Germany Wetherell',
#  'Leblanc',
#  'Jakel',
#  'Lee',
#  'William A. Waas',
#  'Lycan',
#  'Stolp Starduster Corp.',
#  'Robert Judd',
#  'Ultralight Flight, Inc.',
#  'Baugh-hubert',
#  'Sorrell',
#  'Halfpap',
#  'Storey',
#  'Robert B. Boston',
#  'Griffin Trane Inc.',
#  'Interstate',
#  'Humer',
#  'Griffin',
#  'John R Jones',
#  'Howard E. Lee',
#  'Stephens',
#  'Ritz',
#  'Applebay Sailplanes',
#  'Monett-keating',
#  'Rearwin',
#  'Amer. Aerolight',
#  'Peter A. Yarger',
#  'Jordan Henry J',
#  'Entwicklungsgemeinschaft',
#  'Ufm',
#  'Gillmore',
#  'Culver',
#  'Ultralight Soaring',
#  'Haxton',
#  'Jerry D. Fish',
#  'Teraton',
#  'Cessna Wren',
#  'Travel Air',
#  'Experimental Amateur Built',
#  'Morgan T. Melton',
#  'Sperling',
#  'Bobby Wayne Watkins',
#  'Mosley High School',
#  'Vance-hamm',
#  'Nesmith',
#  'Vultee',
#  'Heveron',
#  'Burns',
#  'Sims - Basset',
#  'Intermountain Mfg. (imco)',
#  'E.l. Griggs',
#  'Collins',
#  'S.i. Briggs',
#  'Demick James A',
#  'Bell-olympic Helicopters, Inc.',
#  'Zappia Gabriel J',
#  'Dahlman',
#  'Arnold Forest',
#  'Tate',
#  'Lighthizer, Richard E.',
#  'Darrell W. Mc Moran',
#  'Bakeman-chapman',
#  'Fred Williams',
#  'Lindsay Davis',
#  'Donald E. Bradshaw',
#  'Whitman',
#  'Vaughn',
#  'Bastian',
#  'Hayes',
#  'Calypso',
#  'Shindler-smiley',
#  'Ultralight Ufm',
#  'Universal Stinson',
#  'Russell St. Arnold',
#  'Cessna Ector',
#  'Phaneuf',
#  'Miller Air Sports',
#  'Head Balloons, Inc.',
#  'Ungerecht',
#  'Harris',
#  'Jett',
#  'Denil',
#  'Agusta',
#  'Focke-wulf',
#  'William T. Hodges',
#  'Reicher',
#  'Drake',
#  'Pickel',
#  'Fuller/findlay',
#  'Windecker Research',
#  'Robert Eggebrecht',
#  'Thomas',
#  'Garre Leo J',
#  'Brewer',
#  'Hamburger Flugzeugbau (hfb)',
#  'Kallansrud/pitts',
#  'Mccoy',
#  'Mitchell Ronald A',
#  'Harbaugh John T',
#  'Crosetti',
#  'Harvard',
#  'Light Aero,inc. (ashley)',
#  'Jack L. Bigham',
#  'Four Seasons Aviations',
#  'Moore',
#  'Aspen',
#  'Wells',
#  'Stevens',
#  'Kragnes',
#  'Reed',
#  'Pennington-eaa Biplane',
#  'Donald W Devine',
#  'Corlett-beahm',
#  'Barry Zielinski',
#  'Hart-thorp',
#  'Kenneth Roebuck',
#  'Hardy',
#  'Douglas Swanningson',
#  'Rawdon Bros. Aircraft',
#  'Lounsbery',
#  'Gyrocopter',
#  'Fuji',
#  'Polliwagen',
#  'Crowder',
#  'Saabye',
#  'Emair',
#  'Milentz',
#  'Masselink',
#  'Jim Mckinstry',
#  'Mcclellan J. Grote',
#  'Lyoyd Thompson',
#  'Auton - Dunham',
#  'Benjamin',
#  'Sevdy Pitts Special',
#  'Mitchell Harvey',
#  'Engel',
#  'Aronson',
#  'Stracener Experimental',
#  'Hilliard',
#  'Marr/eckburg',
#  'Kirst Allen J',
#  'Bainbridge',
#  'Ehlers',
#  'Johnson-rand',
#  'Canard, Inc.',
#  'Smelko',
#  'Cirrus',
#  'Sederberg',
#  'Huff',
#  'Condor Aircraft',
#  'Wisconsin State Prison',
#  'Istvanick',
#  'Wheat',
#  'Slingsby',
#  'Mcculloch',
#  'Vickers Slingsby',
#  'Lester F.w. West',
#  'Greer',
#  'Jack Boldt',
#  'Gamble',
#  'Holder',
#  'Centrair',
#  'Dempsey',
#  'Earnst',
#  'Stearman',
#  'Dassault-breguet',
#  'Silvaire',
#  'Airship Industries',
#  'Ringsdorf-mcconnell',
#  'Galloway',
#  'Bedeell',
#  'Heekin',
#  'Steens',
#  'Chadwick',
#  'Jenkins',
#  'E.t. Meredith Iii',
#  'Mcpherson',
#  'Haney',
#  'Briegleb Amature Built',
#  'Otis G. Lyons',
#  'Joel K. Senter',
#  'Hildebrand',
#  'Brians',
#  'General Dynamics',
#  'Killian',
#  'Failing/rand-robinson',
#  'Pzl',
#  'Neumann-everett',
#  'Leslie J. Royal',
#  'Richard E. Rowland',
#  'Borreson',
#  'Kibler-bede',
#  'Shindler',
#  'Kokes',
#  'Quinn Aviation',
#  'Polliwagen Inc.',
#  'Burch',
#  'Lett',
#  'Rand/robinson',
#  'William G. Cloaninger',
#  'Petracca',
#  'Larry Robbins',
#  'Fain',
#  'John H. Mc Clain, Jr.',
#  'Wag-aero, Inc.',
#  'Robert Thibodeau',
#  'Dietz',
#  'New Standard',
#  'Kauffman',
#  'Hazelrige',
#  'Frank H Marchetti',
#  'James Gress',
#  'Woolsey',
#  'Neyman-pietenpol',
#  'Christopher D. Brown',
#  'Schubert',
#  'Stampe',
#  'Larry Schindler',
#  'James Postlewait',
#  'Earl F. Folsom',
#  'Mcfarland',
#  'Jones',
#  'Star Duster Too',
#  'Ronald C. Render',
#  'Richard A. White',
#  'Ronald Houk',
#  'Pezetel',
#  'Mike Stone',
#  'Mar-flite',
#  'Advanced Technology',
#  'Skyranger',
#  'James/viking',
#  'Mitchell/bede',
#  'Duce Project',
#  'Valentin',
#  'Emroth Emair',
#  'Roger W. Stigen',
#  'Jauch',
#  'Welch',
#  'Thornhill',
#  'Pzl-bielsko',
#  'Stolt-adams',
#  "Conover's",
#  'Peterson',
#  'Jonas',
#  'Pitts Spl.',
#  'Laux Pitts',
#  'Todd',
#  'Brokaw',
#  'Vanbenthuysen John',
#  'Wippler',
#  'Lon J. Mcknight',
#  'Challenger',
#  'Univair',
#  'Aerofab Inc.',
#  'Douglas Maselink',
#  'Leone',
#  'Willie',
#  'Skurich',
#  'Leslie',
#  'Hodson',
#  'Ken Brock Mfg. Co',
#  'Ofria',
#  'Silvaggio',
#  'S. Piccolotto/dave Morss',
#  'Saab-fairchild',
#  'Lewis-pexton',
#  'Carothers',
#  'Parsons',
#  'Lonnie W. Ratliff',
#  'Dorfman,william A.',
#  'John Patrick Coleman',
#  'Gary E. Wilson',
#  'Brisbin',
#  'Lagatore',
#  'Gensen',
#  'Bill Mccarley',
#  'Griffin, Thomas',
#  'Douglas C. Campbell',
#  'Robert D. Campbell',
#  'Adams William C',
#  'Monnet',
#  'World Wide Industries',
#  'Socata',
#  'Stephenson',
#  'Commings',
#  'Bushby',
#  'Kuhn',
#  'Universal Aircraft Industries',
#  'Wayne Mathews',
#  'Whigham',
#  'Henley',
#  'Folsom',
#  'Swanningson',
#  'Patrick Henry',
#  'Shaffer',
#  'Durkota',
#  'Jim Elliott',
#  'Ltv',
#  'Glen Davis',
#  'Christen Industries',
#  'Bob White',
#  'Easley',
#  'Joachim Hoehne',
#  'Donald R. Casper',
#  'Perkins',
#  'Morley',
#  'Steinorth',
#  'Rjb Aviation',
#  'Taylor Lonsdale',
#  'Vere Eze',
#  'Blythe',
#  'Baby Bird',
#  'Day',
#  'Ltv Aerospace Industries',
#  'Russell',
#  'Glaser-dirks',
#  'Aviation Adv.',
#  'Wing Aircraft Co.',
#  'Conner',
#  'Hanson',
#  'Wright',
#  'Brewster',
#  'Milliken',
#  'Beaupre Elfering',
#  'Wsk',
#  'Jackman',
#  'Myers',
#  'Collin Campbell',
#  'Denney Aerocraft',
#  'Soward',
#  'Jerry Cox',
#  'Langeford',
#  'Fly Baby',
#  'Arbaugh Evans',
#  'Morris B. Stephens',
#  'Hispano Aviacion',
#  "Bauer's Mitchell Wing",
#  'Bernard Darmstadt',
#  'Green',
#  'Air',
#  'Rose',
#  'Hall Christen Eagle',
#  'Nelson/nelson',
#  'Avian',
#  'Carnes',
#  'Randy Tredo',
#  'Beaver',
#  'Sanders',
#  'Repliea 78 Ral',
#  'Robbins',
#  'Bensen-jansen',
#  'Edward R. Merkner',
#  'Quick Silver',
#  'H. Preiss',
#  'Andrew D. Moore',
#  'Mellema',
#  'Steen Skybolt',
#  'Charles S.hatchette',
#  'Mathew M. Kerr',
#  'Piasecki Acft. Corp.',
#  'Lazarini',
#  'Stainbrook',
#  'Jerry Berry',
#  'Goertz Bushby',
#  'Stevenson',
#  'Bell-campbell',
#  'Whittman',
#  'Patton Pitts',
#  'Weiss-haynes',
#  'Rose Rhinehart',
#  'Hansen',
#  'Troutman',
#  'Huizenga',
#  'Randolph R.clark',
#  'Woodrow S.a.',
#  'Kenneth Patsch',
#  'Cherry',
#  'Steven Soper',
#  'Samuel R. Hoskins',
#  'Wheeler',
#  'Bomberger',
#  'Capetown Builders',
#  'Collins Charles A',
#  'Jaks',
#  'Attebery-stainbrook',
#  'Thorp Aero, Inc.',
#  'Pate',
#  'Ward',
#  'Bernard',
#  'E. E. Schilling',
#  'David Gordon',
#  'Senior Aero Sport',
#  'Wise',
#  'Roger Warnell',
#  'Star-lite',
#  'Erickson',
#  'Russell Post',
#  'Brennan',
#  'Mayala',
#  'Passonno',
#  'Hegsted',
#  'Friling/cothern',
#  'Eugene Boos',
#  'Benham',
#  'Phillips',
#  'Lawrence',
#  'Joe Almon',
#  'Shanks/becker',
#  'Ellis',
#  'Tapaszy',
#  'Rarsch',
#  'Murphy',
#  'Forbes-wolfram Special',
#  'Alexander',
#  'Nord (sncan)',
#  'Jerome Dodge',
#  'Inav',
#  'Star Duster',
#  'Mccoy Robert-michael',
#  ...]

# %%
#Changing all values in column 'Make' to upper case
#This will remove the case sensitivity
aviation_df_cln['Make']= aviation_df_cln['Make'].str.upper()
aviation_df_cln['Make']
# Out:
# 0                           STINSON
# 1                             PIPER
# 2                            CESSNA
# 3                          ROCKWELL
# 4                            CESSNA
#                     ...
# 88884                         PIPER
# 88885                      BELLANCA
# 88886    AMERICAN CHAMPION AIRCRAFT
# 88887                        CESSNA
# 88888                         PIPER
# Name: Make, Length: 88889, dtype: object

# %%
#checking for duplicate values with reference to accident number as the unique identifier
aviation_df_cln['Accident.Number'].duplicated().sum()
# Out:
# 26

# %%
#checking for duplicated values in the accident number as the unique identifier
duplicates = aviation_df_cln[aviation_df_cln['Accident.Number'].duplicated()]
print(duplicates)
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 87305  20220111104514           Accident      ERA22LA103  2022-01-08
# 87331  20220309104747           Incident      DCA22WA089  2022-01-15
# 87348  20220801105632           Incident      DCA22WA167  2022-01-22
# 87412  20220212104630           Accident      ERA22LA119  2022-02-11
# 87549  20220323104818           Accident      CEN22LA149  2022-03-18
# 87623  20220406104897           Accident      WPR22LA143  2022-04-02
# 87917  20220614105258           Incident      DCA22WA130  2022-06-05
# 87932  20220608105217           Accident      WPR22LA201  2022-06-07
# 87991  20220623105317           Accident      DCA22LA135  2022-06-18
# 88085  20220726105577           Incident      DCA22WA158  2022-07-02
# 88096  20220804105661           Incident      DCA22WA172  2022-07-04
# 88168  20220802105640           Accident      GAA22WA241  2022-07-16
# 88175  20220718105496           Accident      ERA22FA318  2022-07-17
# 88241  20220727105589           Accident      ERA22FA338  2022-07-26
# 88258  20220730105623           Accident      CEN22LA346  2022-07-28
# 88315  20220808105682           Accident      ERA22LA364  2022-08-06
# 88372  20220818105763           Accident      WPR22FA309  2022-08-18
# 88387  20220822105776           Accident      ERA22LA379  2022-08-20
# 88513  20220915105950           Accident      DCA22LA201  2022-09-11
# 88528  20220921105978           Incident      DCA22WA204  2022-09-14
# 88538  20220918105957           Accident      CEN22FA424  2022-09-17
# 88593  20220929106019           Accident      DCA22WA214  2022-09-28
# 88777  20221112106276           Accident      CEN23MA034  2022-11-12
# 88796  20221121106336           Accident      WPR23LA041  2022-11-18
# 88798  20221122106340           Incident      DCA23WA071  2022-11-18
# 88814  20221123106354           Accident      WPR23LA045  2022-11-22
#
#               Location        Country Injury.Severity Aircraft.damage  \
# 87305    Knoxville, TN  United States       Non-Fatal     Substantial
# 87331       Sukkur, OF       Pakistan             NaN             NaN
# 87348         Kigali,          Rwanda             NaN             NaN
# 87412       Naples, FL  United States       Non-Fatal           Minor
# 87549    Grapevine, TX  United States       Non-Fatal     Substantial
# 87623     Van Nuys, CA  United States       Non-Fatal     Substantial
# 87917     Peshawar, OF  United States             NaN             NaN
# 87932    Hawthorne, CA  United States       Non-Fatal           Minor
# 87991     New York, NY  United States             NaN     Substantial
# 88085      Barcelona,           Spain             NaN             NaN
# 88096            TBD,              MU             NaN             NaN
# 88168        Aaachen,         Georgia             NaN     Substantial
# 88175    Las Vegas, NV  United States           Fatal       Destroyed
# 88241     Portland, AR  United States           Fatal     Substantial
# 88258      Oshkosh, WI  United States       Non-Fatal     Substantial
# 88315      Erwinna, PA  United States       Non-Fatal     Substantial
# 88372  Watsonville, CA  United States           Fatal       Destroyed
# 88387     Bealeton, VA  United States           Minor     Substantial
# 88513      Chicago, IL  United States             NaN             NaN
# 88528         Mumbai,           India             NaN             NaN
# 88538     Longmont, CO  United States           Fatal       Destroyed
# 88593         London,   Great Britain       Non-Fatal             NaN
# 88777       Dallas, TX  United States           Fatal       Destroyed
# 88796    Las Vegas, NV  United States       Non-Fatal     Substantial
# 88798      Marrakech,         Morocco             NaN             NaN
# 88814    San Diego, CA  United States       Non-Fatal     Substantial
#
#       Registration.Number              Make  ...    Engine.Type  \
# 87305              N1308U            CESSNA  ...  Reciprocating
# 87331              VT-MXK            BOEING  ...            NaN
# 87348              ET-AQN            BOEING  ...            NaN
# 87412                N87G       GREAT LAKES  ...  Reciprocating
# 87549              N9469B            CESSNA  ...  Reciprocating
# 87623              N3901L            CESSNA  ...  Reciprocating
# 87917               GYMMD            BOEING  ...            NaN
# 87932              N694PD        BOMBARDIER  ...    Turbo Shaft
# 87991              F-GSPQ            BOEING  ...            NaN
# 88085              EI-EPA            BOEING  ...            NaN
# 88096             HZ-AK73            BOEING  ...            NaN
# 88168              D-HCMB          ROBINSON  ...            NaN
# 88175              N160RA            CESSNA  ...            NaN
# 88241              N214RL  AIR TRACTOR INC.  ...            NaN
# 88258               N79KM   MESCHLER GARY R  ...  Reciprocating
# 88315              N32141              WACO  ...            NaN
# 88372              N740WJ            CESSNA  ...            NaN
# 88387              N52652            BOEING  ...            NaN
# 88513              N963WN            BOEING  ...            NaN
# 88528               GVBZZ            BOEING  ...            NaN
# 88538              N2117Y            CESSNA  ...            NaN
# 88593              TF-FIK            BOEING  ...            NaN
# 88777              N7227C            BOEING  ...            NaN
# 88796                N88E            CESSNA  ...            NaN
# 88798              CS-DVH            CESSNA  ...            NaN
# 88814              166583          SIKORSKY  ...            NaN
#
#                Purpose.of.flight  Total.Fatal.Injuries Total.Serious.Injuries  \
# 87305                   Personal                   0.0                    0.0
# 87331                        NaN                   0.0                    0.0
# 87348                        NaN                   0.0                    0.0
# 87412                   Personal                   0.0                    0.0
# 87549                   Business                   0.0                    0.0
# 87623              Instructional                   0.0                    0.0
# 87917                        NaN                   0.0                    0.0
# 87932                   Business                   0.0                    0.0
# 87991                        NaN                   0.0                    0.0
# 88085                        NaN                   0.0                    0.0
# 88096                        NaN                   0.0                    0.0
# 88168                        NaN                   0.0                    0.0
# 88175              Instructional                   4.0                    0.0
# 88241         Aerial Application                   1.0                    0.0
# 88258                   Personal                   0.0                    0.0
# 88315                   Personal                   0.0                    0.0
# 88372                   Personal                   3.0                    0.0
# 88387                   Business                   0.0                    2.0
# 88513                        NaN                   0.0                    0.0
# 88528                        NaN                   0.0                    0.0
# 88538              Instructional                   3.0                    0.0
# 88593                        NaN                   0.0                    0.0
# 88777                       ASHO                   6.0                    0.0
# 88796              Instructional                   0.0                    0.0
# 88798                        NaN                   0.0                    0.0
# 88814  Public Aircraft - Federal                   0.0                    0.0
#
#       Total.Minor.Injuries  Total.Uninjured  Weather.Condition  \
# 87305                  0.0              4.0                VMC
# 87331                  0.0              0.0                NaN
# 87348                  0.0              0.0                NaN
# 87412                  0.0              2.0                VMC
# 87549                  0.0              2.0                VMC
# 87623                  0.0              8.0                VMC
# 87917                  0.0              0.0                NaN
# 87932                  0.0             11.0                VMC
# 87991                  0.0              0.0                VMC
# 88085                  0.0              0.0                NaN
# 88096                  0.0              0.0                NaN
# 88168                  0.0              0.0                NaN
# 88175                  0.0              0.0                VMC
# 88241                  1.0              0.0                VMC
# 88258                  0.0              2.0                VMC
# 88315                  0.0              2.0                VMC
# 88372                  0.0              0.0                NaN
# 88387                  0.0              2.0                VMC
# 88513                  0.0              0.0                NaN
# 88528                  0.0              0.0                NaN
# 88538                  0.0              0.0                VMC
# 88593                  0.0              2.0                NaN
# 88777                  0.0              0.0                VMC
# 88796                  0.0              3.0                VMC
# 88798                  0.0              0.0                NaN
# 88814                  0.0              4.0                VMC
#
#        Broad.phase.of.flight  \
# 87305                    NaN
# 87331                    NaN
# 87348                    NaN
# 87412                    NaN
# 87549                    NaN
# 87623                    NaN
# 87917                    NaN
# 87932                    NaN
# 87991                    NaN
# 88085                    NaN
# 88096                    NaN
# 88168                    NaN
# 88175                    NaN
# 88241                    NaN
# 88258                    NaN
# 88315                    NaN
# 88372                    NaN
# 88387                    NaN
# 88513                    NaN
# 88528                    NaN
# 88538                    NaN
# 88593                    NaN
# 88777                    NaN
# 88796                    NaN
# 88798                    NaN
# 88814                    NaN
#
#                                            Report.Status Publication.Date
# 87305  The pilot of the Cessna 150s failure to avoid...       14-06-2022
# 87331                                                NaN              NaN
# 87348                                                NaN              NaN
# 87412  The biplane pilots inadequate visual lookout,...       22-09-2022
# 87549  The failure of the pilot of the second aircraf...       05-07-2022
# 87623  The student pilots failure to maintain suffic...       20-07-2022
# 87917                                                NaN              NaN
# 87932  The multi-engine pilot's failure to maintain c...       02-12-2022
# 87991                                                NaN              NaN
# 88085                                                NaN              NaN
# 88096                                                NaN              NaN
# 88168                                                NaN              NaN
# 88175                                                NaN       05-08-2022
# 88241                                                NaN       18-08-2022
# 88258  The failure of the pilot of N694V (RV-8) to ma...       22-09-2022
# 88315                                                NaN       19-09-2022
# 88372                                                NaN       15-09-2022
# 88387                                                NaN       27-09-2022
# 88513                                                NaN              NaN
# 88528                                                NaN              NaN
# 88538                                                NaN       07-10-2022
# 88593                                                NaN              NaN
# 88777                                                NaN       30-11-2022
# 88796                                                NaN       07-12-2022
# 88798                                                NaN              NaN
# 88814                                                NaN       22-12-2022
#
# [26 rows x 23 columns]

# %%
#dropping duplicated rows with reference to Accident Number
aviation_df_drpd =aviation_df_cln.drop_duplicates(subset='Accident.Number', keep='first')

# %%
#confirming the number of resultant rows
aviation_df_drpd.shape
# Out:
# (88863, 23)

# %%
#confirming if duplicated rows are dropped
aviation_df_drpd['Accident.Number'].duplicated().sum()
# Out:
# 0

# %%
aviation_df_drpd.to_csv('AviationDataCleaned.csv')

# %% [markdown]
# ##**Data Manipulation**

# %%
#Adding a column that represents the total number of passengers by adding all total injured and uninjured
aviation_df_drpd['Total.Passengers']=aviation_df_drpd['Total.Fatal.Injuries'] + aviation_df_drpd['Total.Serious.Injuries'] + aviation_df_drpd['Total.Minor.Injuries'] + aviation_df_drpd['Total.Uninjured']
aviation_df_drpd['Total.Passengers']
# Out:
# <ipython-input-18-e8a396bc4763>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aviation_df_drpd['Total.Passengers']=aviation_df_drpd['Total.Fatal.Injuries'] + aviation_df_drpd['Total.Serious.Injuries'] + aviation_df_drpd['Total.Minor.Injuries'] + aviation_df_drpd['Total.Uninjured']
# 0        2.0
# 1        4.0
# 2        NaN
# 3        2.0
# 4        NaN
#         ...
# 88884    1.0
# 88885    0.0
# 88886    1.0
# 88887    0.0
# 88888    2.0
# Name: Total.Passengers, Length: 88863, dtype: float64

# %%
#Getting statistical data on additional row
aviation_df_drpd['Total.Passengers'].describe()
# Out:
# count    74333.000000
# mean         5.843690
# std         26.744801
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          2.000000
# max        576.000000
# Name: Total.Passengers, dtype: float64

# %%
#Top 10 Aircrafts in the dataset
top_10_Make = aviation_df_drpd['Make'].value_counts().head(10)
top_10_Make
# Out:
# Make
# CESSNA      27141
# PIPER       14870
# BEECH        5372
# BOEING       2734
# BELL         2722
# MOONEY       1334
# ROBINSON     1229
# GRUMMAN      1172
# BELLANCA     1045
# HUGHES        932
# Name: count, dtype: int64

# %%
#Identifying the aircrafts that had the top 10 total number of passengers
top_10_carriers = aviation_df_drpd.groupby('Make')['Total.Passengers'].sum().sort_values(ascending=False).head(10)
top_10_carriers
# Out:
# Make
# BOEING               177211.0
# CESSNA                47057.0
# MCDONNELL DOUGLAS     37573.0
# PIPER                 26895.0
# AIRBUS                20447.0
# AIRBUS INDUSTRIE      13842.0
# BEECH                 11768.0
# DOUGLAS                8674.0
# LOCKHEED               7075.0
# BELL                   5206.0
# Name: Total.Passengers, dtype: float64

# %%
#viewing correlation between int and float data
aviation_df.select_dtypes(include=['int', 'float']).corr()
# Out:
#                         Number.of.Engines  Total.Fatal.Injuries  \
# Number.of.Engines                1.000000              0.098505
# Total.Fatal.Injuries             0.098505              1.000000
# Total.Serious.Injuries           0.046157              0.135724
# Total.Minor.Injuries             0.098162              0.073559
# Total.Uninjured                  0.406058             -0.015214
#
#                         Total.Serious.Injuries  Total.Minor.Injuries  \
# Number.of.Engines                     0.046157              0.098162
# Total.Fatal.Injuries                  0.135724              0.073559
# Total.Serious.Injuries                1.000000              0.326849
# Total.Minor.Injuries                  0.326849              1.000000
# Total.Uninjured                       0.052869              0.147770
#
#                         Total.Uninjured
# Number.of.Engines              0.406058
# Total.Fatal.Injuries          -0.015214
# Total.Serious.Injuries         0.052869
# Total.Minor.Injuries           0.147770
# Total.Uninjured                1.000000

# %% [markdown]
# #**Visualisation**
# Answering objectives through visualisation

# %% [markdown]
# ##**Descriptive Visualisations**

# %% [markdown]
# ###**Pairplot**

# %%
# Creating a pairplot
sns.pairplot(aviation_df_drpd)

# %% [markdown]
# Observation:
# There are some relations viewed between number of engines and variables such total fatal, serious injuries and uninjured,total passengers

# %% [markdown]
# ###**Heatmap**
# Checking for correlation between the int and float variables

# %%
#viewing correlation between int and float data
aviation_df.select_dtypes(include=['int', 'float']).corr()
# Out:
#                         Number.of.Engines  Total.Fatal.Injuries  \
# Number.of.Engines                1.000000              0.098505
# Total.Fatal.Injuries             0.098505              1.000000
# Total.Serious.Injuries           0.046157              0.135724
# Total.Minor.Injuries             0.098162              0.073559
# Total.Uninjured                  0.406058             -0.015214
#
#                         Total.Serious.Injuries  Total.Minor.Injuries  \
# Number.of.Engines                     0.046157              0.098162
# Total.Fatal.Injuries                  0.135724              0.073559
# Total.Serious.Injuries                1.000000              0.326849
# Total.Minor.Injuries                  0.326849              1.000000
# Total.Uninjured                       0.052869              0.147770
#
#                         Total.Uninjured
# Number.of.Engines              0.406058
# Total.Fatal.Injuries          -0.015214
# Total.Serious.Injuries         0.052869
# Total.Minor.Injuries           0.147770
# Total.Uninjured                1.000000

# %%
# Visualization heatmap
plt.figure(figsize=(12,8))
sns.heatmap(aviation_df_drpd.select_dtypes(include=['int', 'float']).corr(),annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# Observation
#
#
# *   Not much correlation between the int and float columns

# %% [markdown]
# ###**Histograms**
# Identifying the distribution of number of engines in the accident log

# %%
# Histogram
plt.figure(figsize=(10, 6))
sns.histplot(aviation_df_drpd['Number.of.Engines'])
plt.title('Distribution of Number of Engines')
plt.xlabel('Number of Engines')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# %% [markdown]
# Observation
#
# *   Majority of aircrafts that were in accidents had 1 engine
# *   Majority of aircrafts had 1 or 2 engines

# %% [markdown]
# ###**BarGraphs**

# %% [markdown]
# ####**BarGraph 1**
# Visualising the top 10 carriers

# %%
# Creating a bar graph for total passengers per make (top 10)
plt.figure(figsize=(8, 6))  # Set figure size
top_10_carriers.plot(kind='bar', color='steelblue')
# Out:
# <Axes: xlabel='Make'>

# %% [markdown]
# Observation:
#
#
# *   This shows that Boeing has the highest number of passengers per aircraft

# %% [markdown]
# ####**BarGraph2**
# Largest number of a particular on the Dataset

# %%
# Creating a bar graph for total count of airraft data per make (top 10)
plt.figure(figsize=(8, 6))  # Set figure size
top_10_Make.plot(kind='bar', color='steelblue')
# Out:
# <Axes: xlabel='Make'>

# %% [markdown]
# Observation:
#
# *   This shows that the CESSNA aircraft has high tendencies to have accidents as its the most populated on the dataset

# %% [markdown]
# ####**BarGraph3**
# Major Purpose of flight

# %%
#Identifying the major purpose of flights
plt.figure(figsize=(8, 6))  # Set figure size
aviation_df_drpd['Purpose.of.flight'].value_counts().head(10).plot(kind='bar', color='steelblue')
# Out:
# <Axes: xlabel='Purpose.of.flight'>

# %% [markdown]
# Observation
# Most aircraft accidents are from personal use. This could be due to training or recreational activities

# %% [markdown]
# ##**Objective 1**
# Which is the safest or most unsafe aircrafts and why

# %% [markdown]
# ### **Aircraft with sum of the highest fatal injuries**

# %%
# Combining 'make' and 'model' into a single column for grouping
aviation_df_drpd['Make_Model'] = aviation_df_drpd['Make'].str.upper() + aviation_df_drpd['Model']
# Group by the combined 'make_model' and sum based on fatal injuries
accident_sum = aviation_df_drpd.groupby('Make_Model')['Total.Fatal.Injuries'].sum().reset_index(name='Accident_sum')

top_10_sum_accidents = accident_sum.sort_values(by='Accident_sum', ascending=False).head(20)
# Plotting the bar graph
sns.barplot(x='Make_Model', y='Accident_sum', data=top_10_sum_accidents)

plt.title('Total Number of Accidents by Aircraft Make and Model')
plt.xlabel('Make and Model of Aircraft')
plt.ylabel('Number of Fatal Injuries')


plt.tight_layout()
#orienting the labels on the axis rotated to 45 degrees
plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# <ipython-input-43-be699623beda>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aviation_df_drpd['Make_Model'] = aviation_df_drpd['Make'].str.upper() + aviation_df_drpd['Model']

# %% [markdown]
# Observation
#
#
# 1.   Boeing 737 aircrafts have the highest number of casulaties - Boeing typically has more passengers and therefore it is expected to have more casualities

# %% [markdown]
# ### **Aircraft with count of the highest fatal injurie**s

# %%
# Group by the combined 'make_model' and count based on fatal injuries
accident_counts = aviation_df_drpd.groupby('Make_Model')['Total.Fatal.Injuries'].count().reset_index(name='Accident_count')

top_10_count_accidents = accident_counts.sort_values(by='Accident_count', ascending=False).head(20)
# Plotting the bar graph
sns.barplot(x='Make_Model', y='Accident_count', data=top_10_count_accidents)

plt.title('Total Number of Accidents by Aircraft Make and Model')
plt.xlabel('Make and Model of Aircraft')
plt.ylabel('Number of Fatal Injuries')


plt.tight_layout()
#orienting the labels on the axis rotated to 45 degrees
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# Observation
# CESSNA aircrafts have a higher count on accidents
# this is expected since they are smaller aircrafts used for training and personal use as seen in BarGraph3 above

# %% [markdown]
# ###**Correlation between number of engines and total fatalitie**s

# %%
#Identifying the correlation between the number of fatalities
engine_corr = aviation_df_drpd.groupby('Number.of.Engines')['Total.Fatal.Injuries'].sum().reset_index(name='Fatalities')
engine_corr.sort_values(by='Fatalities',ascending=False).head(10)
# Out:
#    Number.of.Engines  Fatalities
# 1                1.0     22123.0
# 2                2.0     10518.0
# 4                4.0      1660.0
# 3                3.0       878.0
# 0                0.0       409.0
# 5                6.0         0.0
# 6                8.0         0.0

# %%
# Creating a barplot of number of engines vs Total Fatal Injuries
sns.barplot(x='Number.of.Engines', y='Fatalities', data = engine_corr)

plt.title('Effect of Number of Engines on Fatalities')



plt.tight_layout()
#orienting the labels on the axis rotated to 45 degrees
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# Observation:
#
#
# *   Aircrafts with one engine had a higher number of fatalities then 2 engines
#
#
#
#
#
# 1.   This is because for personal flights, which have one engine(typically fewer passengers), there is higher likelihood all passengers to have fatal injuries
# 2.   For aircraft with 2 engines, the likelihood to have high fatalities is because the aircraft has more pssengers and hence increased fatalities

# %% [markdown]
# Make of aircraft vs Number of engines

# %%
#This shows the breakdown of the Makes vs Number of engines
counts = aviation_df_drpd.groupby(['Number.of.Engines', 'Make']).size().reset_index(name='count')

# Sort by count in descending order and take top 20
top_20 = counts.sort_values('count', ascending=False).head(20)

# Print the results in a formatted way
print("\nTop 20 Aircraft by Make and Engine Count:")
print("=======================================")


# Ranking list
for idx, row in top_20.iterrows():
    rank = idx + 1
    print(f"{rank:2d}. {row['Make']} ({row['Number.of.Engines']} Number.of.Engines) - {row['count']} aircraft")
# Out:
# Top 20 Aircraft by Make and Engine Count:
# =======================================
# 1322. CESSNA (1.0 Number.of.Engines) - 23845 aircraft
# 5048. PIPER (1.0 Number.of.Engines) - 12219 aircraft
# 766. BEECH (1.0 Number.of.Engines) - 3107 aircraft
# 7265. CESSNA (2.0 Number.of.Engines) - 2299 aircraft
# 783. BELL (1.0 Number.of.Engines) - 2270 aircraft
# 7445. PIPER (2.0 Number.of.Engines) - 2133 aircraft
# 7228. BEECH (2.0 Number.of.Engines) - 1985 aircraft
# 4559. MOONEY (1.0 Number.of.Engines) - 1301 aircraft
# 2802. GRUMMAN (1.0 Number.of.Engines) - 1056 aircraft
# 812. BELLANCA (1.0 Number.of.Engines) - 1027 aircraft
# 5496. ROBINSON (1.0 Number.of.Engines) - 1016 aircraft
# 7235. BOEING (2.0 Number.of.Engines) - 882 aircraft
# 3269. HUGHES (1.0 Number.of.Engines) - 881 aircraft
# 351. AIR TRACTOR (1.0 Number.of.Engines) - 649 aircraft
# 301. AERONCA (1.0 Number.of.Engines) - 632 aircraft
# 4251. MAULE (1.0 Number.of.Engines) - 574 aircraft
# 1344. CHAMPION (1.0 Number.of.Engines) - 502 aircraft
# 6245. STINSON (1.0 Number.of.Engines) - 437 aircraft
# 4104. LUSCOMBE (1.0 Number.of.Engines) - 409 aircraft
# 6395. TAYLORCRAFT (1.0 Number.of.Engines) - 376 aircraft
# 5806. SCHWEIZER (1.0 Number.of.Engines) - 372 aircraft
# 941. BOEING (1.0 Number.of.Engines) - 366 aircraft
# 4778. NORTH AMERICAN (1.0 Number.of.Engines) - 346 aircraft
# 3128. HILLER (1.0 Number.of.Engines) - 340 aircraft
# 2189. ENSTROM (1.0 Number.of.Engines) - 287 aircraft
# 7524. BOEING (3.0 Number.of.Engines) - 264 aircraft
# 314. AEROSPATIALE (1.0 Number.of.Engines) - 261 aircraft
# 5508. ROCKWELL (1.0 Number.of.Engines) - 259 aircraft
# 1807. DE HAVILLAND (1.0 Number.of.Engines) - 257 aircraft
# 7411. MCDONNELL DOUGLAS (2.0 Number.of.Engines) - 231 aircraft
# 5497. ROBINSON HELICOPTER (1.0 Number.of.Engines) - 228 aircraft
# 7547. BOEING (4.0 Number.of.Engines) - 226 aircraft
# 628. AYRES (1.0 Number.of.Engines) - 224 aircraft
# 2808. GRUMMAN AMERICAN (1.0 Number.of.Engines) - 221 aircraft
# 1416. CIRRUS DESIGN CORP (1.0 Number.of.Engines) - 221 aircraft
# 277. AERO COMMANDER (1.0 Number.of.Engines) - 217 aircraft
# 192. SCHWEIZER (0.0 Number.of.Engines) - 211 aircraft
# 352. AIR TRACTOR INC (1.0 Number.of.Engines) - 205 aircraft
# 5501. ROBINSON HELICOPTER COMPANY (1.0 Number.of.Engines) - 191 aircraft
# 7189. AERO COMMANDER (2.0 Number.of.Engines) - 187 aircraft
# 2220. EUROCOPTER (1.0 Number.of.Engines) - 178 aircraft
# 7306. EMBRAER (2.0 Number.of.Engines) - 167 aircraft
# 7203. AIRBUS (2.0 Number.of.Engines) - 167 aircraft
# 2193. ERCOUPE (ENG & RESEARCH CORP.) (1.0 Number.of.Engines) - 160 aircraft
# 7499. SWEARINGEN (2.0 Number.of.Engines) - 160 aircraft
# 5071. PITTS (1.0 Number.of.Engines) - 148 aircraft
# 3863. LAKE (1.0 Number.of.Engines) - 142 aircraft
# 6801. WACO (1.0 Number.of.Engines) - 140 aircraft
# 7299. DOUGLAS (2.0 Number.of.Engines) - 138 aircraft
# 606. AVIAT (1.0 Number.of.Engines) - 138 aircraft

# %% [markdown]
# Observation:
#
#
# *   From the above data we see that the BEECH, then BOEING aircrafts have the highest number of aircrafts with 2 engines and from Bar graph 1, they both have the highest number of passengers for a 2 engine aircraft that are large carriers

# %% [markdown]
# ###**Aircraft with the most damage and with the least uninjured passengers**

# %%
# Getting the top 10 aircraft makes based on frequency
top_5_makes = aviation_df_drpd['Make'].value_counts().head(5).index

# Filtering the data to include only the top 10 makes
df_top_5 = aviation_df_drpd[aviation_df_drpd['Make'].isin(top_5_makes)]

# Creating a boxplot showing Aircraft Damage vs Total Uninjured, colored by Aircraft Make (hue)
plt.figure(figsize=(12, 6))
sns.barplot(x="Aircraft.damage", y="Total.Uninjured", hue="Make", data=df_top_5)

# Title and labels
plt.title("Barplot: Aircraft Damage vs Total Uninjured by Aircraft Make")
plt.xlabel("Aircraft Damage")
plt.ylabel("Total Uninjured")

#Plot
plt.show()

# %% [markdown]
# Observation:
#
#
# *   From the above graph we see that BOEING followed by BEECH have the highest number of uninjured passengers relative to the aircraft damage

# %% [markdown]
# ##**Objective 2**
# What is the major cause of accidents

# %% [markdown]
# ###**Phase of flight that causes most accidents**

# %%
# Creating a countplot showing the count of records by Phase of Flight, with aircraft damage categories as hue
plt.figure(figsize=(12, 6))
sns.countplot(x="Broad.phase.of.flight", hue="Aircraft.damage", data=aviation_df_drpd, palette="Set2")

# Title and labels
plt.title("Count of Records by Phase of Flight and Aircraft Damage")
plt.xlabel("Phase of Flight")
plt.ylabel("Count")

# Show the plot
plt.show()

# %% [markdown]
# Observation:
#
#
# *   The above data shows that landing is the highest cause of accidents in relation to aircraft damage

# %% [markdown]
# ###**Effect of weather on fatalities**

# %%
#Grouping fatalities by wwether condition
weather_eff = aviation_df_drpd.groupby('Weather.Condition')['Total.Fatal.Injuries'].sum().reset_index(name='Fatalities')

weather_eff.sort_values(by='Fatalities',ascending=False).head(10)
# Creating a barplot of number of engines vs Total Fatal Injuries
sns.barplot(x='Weather.Condition', y='Fatalities', data = weather_eff)

plt.title('Effect of Weather on Fatalities')

plt.tight_layout()

plt.show()

# %% [markdown]
# Observation:
#
#
# *   VNC - Visual Navigation Conditions -conditions that are suitable for visual navigation.
# *   IMC - Instrument Meteorological Conditions -conditions that are below the minimums required for visual flight.
# *   UNK - UNK is a shorthand for "unknown", and it is used when the data about a certain condition cannot be determined.
#
# From the above we can see that the weather had little to no effect on the fatalities. Fatalities were realised even in perfect weather conditions

# %% [markdown]
# ###**Effect of build on Fatalities**

# %%
#Grouping fatalities by aircraft build
aircraft_build = aviation_df_drpd.groupby('Amateur.Built')['Total.Fatal.Injuries'].sum().reset_index(name='Fatalities')

aircraft_build.sort_values(by='Fatalities',ascending=False).head(10)
# Creating a barplot of number of engines vs Total Fatal Injuries
sns.barplot(x='Amateur.Built', y='Fatalities', data = aircraft_build)

plt.title('Effect of Aircraft Build on Fatalities')

plt.tight_layout()

plt.show()

# %% [markdown]
# Observation:
#
#
#
# *   From the above visualisation we can see that most of the fatalities did not occur from a plane built by non professional manufacturers

# %% [markdown]
# ##**Objective 3**

# %% [markdown]
# ###**Which year had the most fatalities**

# %%
# Converting the 'Date' column to datetime type
aviation_df_drpd['Publication.Date'] = pd.to_datetime(aviation_df_drpd['Publication.Date'])

# Extracting the year from the 'Date' column
aviation_df_drpd['Year'] = aviation_df_drpd['Publication.Date'].dt.year

# Grouping by year and sum the fatalities (or count if necessary)
yearly_fatalities = aviation_df_drpd.groupby('Year')['Total.Fatal.Injuries'].sum().reset_index()

# Creating a line plot
plt.figure(figsize=(12, 6))
sns.lineplot(data=yearly_fatalities, x='Year', y='Total.Fatal.Injuries')

# Title and labels
plt.title('Fatalities by Year', fontsize=16)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Total Fatalities', fontsize=12)

# Show the plot
plt.show()
# Out:
# <ipython-input-126-fbaaaa84d6e0>:2: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   aviation_df_drpd['Publication.Date'] = pd.to_datetime(aviation_df_drpd['Publication.Date'])
# <ipython-input-126-fbaaaa84d6e0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aviation_df_drpd['Publication.Date'] = pd.to_datetime(aviation_df_drpd['Publication.Date'])
# <ipython-input-126-fbaaaa84d6e0>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aviation_df_drpd['Year'] = aviation_df_drpd['Publication.Date'].dt.year

# %% [markdown]
# Observation:
#
# *   Year 2020 had the highest number of fatalities. This could be due to the world-wide lockdown in relation to Covid19 and therefore a high increase in recreational activities to reduce boredom

# %% [markdown]
# #**Findings**
#
#
#
# *   From the above analysis, we have found that;
#
#
#
#
# 1.   The unsafest aircraft is the Boeing 737 and 777 followed by Cessna 172N. This investigation considers the total number of fatalities per model and make
# 2.   We have also found that the safest aircraft in relation to the total number of uninjured passengers is BOEING followed by BEECH
# 3.   The aircraft with the most occurence on the dataset is Cessna
# 4.   The number and type of engines is a contributing factor to the fatalities/uninjured
# 5.   The major cause of accidents in flights is;
# *   Landing
# *   Purpose of flight : Personal
# 6. The weather and the amateur built aircrafts had no direct impact of the fatalities
# 7. 2020 registered the highest number of fatalities

# %% [markdown]
# #**Conclusion**
#
# The conclusion is as below;
#
#
#
# 1.   The safest aircraft is the Boeing series, followed by Beech.Why;
#
#
# *   It had the highest number of uninjured passengers. This is attributed to its number of engines(2 and 4). This means that in the event of a loss of 1 engine the other would take over.
# *   Since it is a huge carrier, and a public carrier, there are more stringent rules on training of the pilots to reduce the fatalities.
#
# 2.   The unsafest aircraft is the Cessna series. Why;
#
# *   The Cessna series is a small aircraft that is most used for training and personal purposes such as recreation. Due to its small number of passengers, it has less stringent rules and therefore more probability to have large number of fatalities
# *   Its engine number and type being small may not be able to reduce casualties
#
# 3. The reason for most accidents;
#
#
# *   This has been found to be landing of the plane
# *   The purpose of flight is personal - highly likely being recreational

# %% [markdown]
# #**Recommendations**
#
# ##**For commercial purposes;**
#
# 1. The business should consider working with aircrafts with larger carrying capacity and more engines - greater than 2. The recommended aircraft is Boeing and Beech.
#
# ##**For private purposes;**
# 1. The Piper aircraft is safer as it has the same size as the Cessna but with fewer casualties
# 2. The pilots should have enhanced training on landing aircrafts
# 3. The company should first focus on aircrafts for training as opposed to recreation to reduce fatalities and avoid the risk of brand reputation and potentially impact the bottom line.
